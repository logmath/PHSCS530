# %% [markdown]
# # PHSCS 530
# # Homework 01: Preliminaries

# %%
import numpy as np
import matplotlib.pyplot as plt

# Experimenting with changing plot styles. I have written a sizeable function in MATLAB to customize almost all plot defaults 
# easily in a user-friendly interface, which I will likely do with Python as well. For now, I'm just learning.
import matplotlib.style
import matplotlib as mpl
from cycler import cycler
# Set default axes color order to Okabe Ito color-safe palette
mpl.rcParams['axes.prop_cycle'] = cycler('color',['#D55E00','#0072B2','#009E73','#E69F00','#56B4E9','#CC79A7','#F0E442','#000000'])
mpl.rcParams['image.cmap'] = 'inferno' # Set default colormap to inferno, a perceptually-uniform map
mpl.rcParams['font.size'] = 16
mpl.rcParams['font.sans-serif'] = 'Arial' # Arial is a good approximation for Helvetica
mpl.rcParams['grid.linestyle'] = ':'
mpl.rcParams['grid.color'] = '#646464'

# %% [markdown]
# ### Part A

# %%
N = 50;
x = np.linspace(0,2*np.pi,N)
y = np.exp(-6*np.sin(xn))

plt.figure()
plt.plot(x,y,color = 'g', marker = 'o') # set color to green, add markers at data points
plt.xlabel(r'$x_n$')
plt.ylabel(r'$\exp[-6\,\sin(x_n)]$')
plt.grid()
plt.savefig('HW01_A_01.svg') # save plot

plt.ylim([0,1]) # zoom into y-axis range between 0 and 1
plt.savefig('HW01_A_02.svg') # save updated plot

# %% [markdown]
# ### Part B

# %%
data = np.genfromtxt('NoisyFunction.dat') # import data file
t = data[:,0] # first column of data
y = data[:,1] # second column of data

plt.figure()
plt.scatter(t,np.log(y**2))
plt.xlabel(r'$t_n$')
plt.ylabel(r'$\log(y^2)$')
plt.savefig('HW01_B.svg')
